# %% [markdown]
# <a href="https://colab.research.google.com/github/Engineering2026/Engineering2026.github.io/blob/main/LeapYear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year = int(input("Enter a year: "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
  print(year, "is a leap year")
else:
  print(year, "is not a leap year")
# Out:
# Enter a year: 2000
# 2000 is a leap year
