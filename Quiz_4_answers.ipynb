# %% [markdown]
# <a href="https://colab.research.google.com/github/Engineering2026/Engineering2026.github.io/blob/main/Quiz_4_answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
words = ["data", "science", "ai"]
a = words
b = words[:]
a[0] = "big"
b[1] = "machine"
print(words)
# Out:
# ['big', 'science', 'ai']

# %%
words = ["cat", "dog", "elephant", "ant"]
result = [w for w in words if len(w) > 3]
print(result)
# Out:
# ['elephant']

# %%
parts = ["EE", "1108", "Python"]
s = "-".join(parts)
print(s)
# Out:
# EE-1108-Python

# %%
words = ["apple", "banana", "cherry"]
for w in words:
  if "a" in w:
      words.remove(w)
print(words)
# Out:
# ['banana', 'cherry']

# %%
words = ["pear", "Apple", "banana"]
words.sort()
print(words)
# Out:
# ['Apple', 'banana', 'pear']

# %%
data = [["a", "b"], ["c", "d"], ["e"]]
count = 0
for sub in data:
  for item in sub:
    count += len(item)
print(count)
# Out:
# 5

# %%
words = ["EE", "is", "fun"]
result = ""
for w in words:
  result += w[0]
print(result)
# Out:
# Eif
