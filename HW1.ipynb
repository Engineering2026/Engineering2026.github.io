# %% [markdown]
# <a href="https://colab.research.google.com/github/Engineering2026/Engineering2026.github.io/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Please enter your user name: ")
print(f"Hello, {name}!")
# Out:
# Please enter your user name: Justin
# Hello, Justin!

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
print("Sum:", num1 + num2)
print("Difference:", num1 - num2)
print("Product:", num1 * num2)
if num2 != 0:
  print("Quotient:", num1 / num2)
else:
  print("Quotient: undefined (cannot divide by zero)")
# Out:
# Enter the first number: 10
# Enter the second number: 0
# Sum: 10.0
# Difference: 10.0
# Product: 0.0
# Quotient: undefined (cannot divide by zero)

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"Temperature in Fahrenheit: {fahrenheit}")
# Out:
# Enter temperature in Celsius: 32
# Temperature in Fahrenheit: 89.6
